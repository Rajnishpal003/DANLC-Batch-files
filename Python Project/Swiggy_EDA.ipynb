# %%
#importing all libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read csv file
df=pd.read_csv("C:\\Users\\Shivangi\\OneDrive\\Desktop\\Shivangi Singh\\Swiggy data analysis\\Swiggy_dataset.csv")

# %%
#first 5 rows
df.head()
# Out:
#   type      id                       name  \
# 0    F   37933     Faasos - Wraps & Rolls
# 1    F   81814                Burger King
# 2    F  107046        Mahalaxmi Pav Bhaji
# 3    F  328315                 HIIT Meals
# 4    F  108879  Jay Jalaram Parotha House
#
#                                    uuid       city         area avgRating  \
# 0  6fe9caf1-02a7-4e66-83bb-1b4ff296b683  Ahmedabad    Vastrapur       4.2
# 1  10083576-d32d-4a0e-8a82-3236ef342a19  Ahmedabad  Ellisbridge       4.2
# 2  fbfe3bfa-03fd-4708-b913-06e2c9ee9639  Ahmedabad  Ellisbridge       4.3
# 3  81ab4019-2445-4aef-aff2-04beccd641d9  Ahmedabad      Vishala        --
# 4  994e73e1-7c7c-4ad9-87e7-ecfecd4e36fa  Ahmedabad  Ellisbridge       3.9
#
#   totalRatingsString                                           cuisines  \
# 0       500+ ratings  ['Combo' 'Snacks' 'Beverages' 'Desserts' 'Indi...
# 1      1000+ ratings                           ['American' 'Fast Food']
# ...

# %%
#last 5 rows
df.tail()
# Out:
#      type      id                                name  \
# 8686    F  452149      RAJWADU KATHIYAWADI RESTAURANT
# 8687    F  411690                  Concord Restaurant
# 8688    F  409122  5 Hot Chillis Pizza & Mocktail bar
# 8689    F  438809             SHIVA GARDEN RESTAURANT
# 8690    F  425118            Waterbomb pani-puri shop
#
#                                       uuid   city      area avgRating  \
# 8686  0db4b5d1-4db2-44cc-9cec-5042ccba778b  Surat    Adajan        --
# 8687  6f112782-e1c0-477f-8c5b-3a7011d2dd7d  Surat    Adajan         4
# 8688  f0be3849-3d95-4ac9-bcd0-14a8501d98d7  Surat  Sarthana        --
# 8689  6cf08b59-b6e1-4ffe-be07-a895c8816d58  Surat  Sarthana        --
# 8690  12fde98a-36df-4bd8-95a8-7a05e1202025  Surat  Sarthana        --
#
#      totalRatingsString                                           cuisines  \
# 8686    Too Few Ratings  ['Gujarati' 'Indian' 'Fast Food' 'Pizzas' 'Bev...
# ...

# %%
#shape of data(no of rows and columns)
df.shape
# Out:
# (8691, 18)

# %%
#information about our dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8691 entries, 0 to 8690
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   type                8691 non-null   object
#  1   id                  8691 non-null   int64
#  2   name                8691 non-null   object
#  3   uuid                8688 non-null   object
#  4   city                8691 non-null   object
#  5   area                8691 non-null   object
#  6   avgRating           8691 non-null   object
#  7   totalRatingsString  8691 non-null   object
#  8   cuisines            8691 non-null   object
#  9   costForTwoStrings   8691 non-null   object
#  10  deliveryTime        8691 non-null   int64
#  11  minDeliveryTime     8691 non-null   int64
#  12  maxDeliveryTime     8691 non-null   int64
#  13  address             8682 non-null   object
#  14  locality            8681 non-null   object
# ...

# %%
#statistical summary of data
df.describe()
# Out:
#                   id  deliveryTime  minDeliveryTime  maxDeliveryTime  City
# count    8691.000000   8691.000000      8691.000000      8691.000000   0.0
# mean   244855.957887     53.959268        53.130480        53.130480   NaN
# std    158650.520513     14.290555        13.701142        13.701142   NaN
# min       211.000000     20.000000        20.000000        20.000000   NaN
# 25%     72885.500000     44.000000        44.000000        44.000000   NaN
# 50%    283560.000000     52.000000        52.000000        52.000000   NaN
# 75%    393448.500000     64.000000        63.000000        63.000000   NaN
# max    466928.000000    109.000000       109.000000       109.000000   NaN

# %%
#find missing value 
df.isnull().sum()
# Out:
# type                     0
# id                       0
# name                     0
# uuid                     3
# city                     0
# area                     0
# avgRating                0
# totalRatingsString       0
# cuisines                 0
# costForTwoStrings        0
# deliveryTime             0
# minDeliveryTime          0
# maxDeliveryTime          0
# address                  9
# locality                10
# unserviceable            6
# veg                      6
# City                  8691
# dtype: int64

# %%
#dropping city column
df.drop(columns='City',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8691 entries, 0 to 8690
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   type                8691 non-null   object
#  1   id                  8691 non-null   int64
#  2   name                8691 non-null   object
#  3   uuid                8688 non-null   object
#  4   city                8691 non-null   object
#  5   area                8691 non-null   object
#  6   avgRating           8691 non-null   object
#  7   totalRatingsString  8691 non-null   object
#  8   cuisines            8691 non-null   object
#  9   costForTwoStrings   8691 non-null   object
#  10  deliveryTime        8691 non-null   int64
#  11  minDeliveryTime     8691 non-null   int64
#  12  maxDeliveryTime     8691 non-null   int64
#  13  address             8682 non-null   object
#  14  locality            8681 non-null   object
# ...

# %%
#dropping uuid columns with missing values
df.dropna(subset=['uuid','address','locality'],inplace=True)

# %%
df['unserviceable'].fillna('False')          
df['veg'].fillna('False')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 8686     True
# 8687    False
# 8688     True
# 8689     True
# 8690     True
# Name: veg, Length: 8669, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8669 entries, 0 to 8690
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   type                8669 non-null   object
#  1   id                  8669 non-null   int64
#  2   name                8669 non-null   object
#  3   uuid                8669 non-null   object
#  4   city                8669 non-null   object
#  5   area                8669 non-null   object
#  6   avgRating           8669 non-null   object
#  7   totalRatingsString  8669 non-null   object
#  8   cuisines            8669 non-null   object
#  9   costForTwoStrings   8669 non-null   object
#  10  deliveryTime        8669 non-null   int64
#  11  minDeliveryTime     8669 non-null   int64
#  12  maxDeliveryTime     8669 non-null   int64
#  13  address             8669 non-null   object
#  14  locality            8669 non-null   object
# ...

# %%
df.dropna(subset=['unserviceable','veg'],inplace=True)

# %%
df.isnull().sum()
# Out:
# type                  0
# id                    0
# name                  0
# uuid                  0
# city                  0
# area                  0
# avgRating             0
# totalRatingsString    0
# cuisines              0
# costForTwoStrings     0
# deliveryTime          0
# minDeliveryTime       0
# maxDeliveryTime       0
# address               0
# locality              0
# unserviceable         0
# veg                   0
# dtype: int64

# %%
df['avgRating'] = df['avgRating'].replace('--', np.nan).astype(float)

# %%
#checking shape of final cleaned data
df.shape
# Out:
# (8668, 17)

# %%
df.to_csv('C:\\Users\\Shivangi\\OneDrive\\Desktop\\Swiggy_cleaned_dataset.csv',index=False)

# %%
print("Cleaned file saved at path")
# Out:
# Cleaned file saved at path

# %%
#plotting graphs for visulaization
#Distribution of average rating
plt.figure(figsize=(8,5))
sns.histplot(df['avgRating'],bins=10,color='blue')
plt.title("Distribution of average rating")
plt.xlabel('Average Rating')
plt.ylabel('Frequency')
plt.show()

# %%
#Average rating by city analysis
avgrating_by_city=df.groupby('city')['avgRating'].mean().sort_values(ascending=True)
avgrating_by_city.plot(kind='bar',color='green')
plt.title("Average rating by city")
plt.xlabel("City")
plt.ylabel("Average rating")
# Out:
# Text(0, 0.5, 'Average rating')

# %%
#Top 5 Popular Cuisines
cuisines_count=df['cuisines'].value_counts().head()
plt.pie(cuisines_count,labels=cuisines_count.index,autopct='%1.1f%%')
plt.title("Top 5 Popular Cuisines")
plt.show()

# %%
#Count of Veg and Non-veg Restaurants Analysis
veg_count=df['veg'].value_counts()
veg_count.plot(kind='bar',color=['orange','green'])
plt.title("Count of Veg and Non-veg Restaurants")
plt.xlabel("Veg and Non-veg")
plt.ylabel("Count")
plt.show()

# %%
#Delivery Time by City Analysis
plt.figure(figsize=(10,8))
sns.boxplot(x='city',y='deliveryTime',data=df)
plt.title("Delivery Time by City")
plt.xlabel("City")
plt.ylabel("Delivery Time")
plt.grid(True)
plt.show()

# %%
df['costForTwoStrings'] = pd.to_numeric(df['costForTwoStrings'], errors='coerce')

# %%
#Total Rating Vs Avg. Rating
plt.figure(figsize=(10,8))
plt.scatter(df['totalRatingsString'], df['avgRating'], alpha=0.6, color='green')
plt.title("Total Rating Vs Avg. Rating")
plt.xlabel("Total Rating")
plt.ylabel("Average Rating")
plt.show()

# %%
# Delivery Time Range (Min vs. Max) Analysis
plt.figure(figsize=(14, 6))
df[['minDeliveryTime', 'maxDeliveryTime']].plot(kind='box', patch_artist=True, figsize=(10, 6))
plt.title("Delivery Time Range (Min vs. Max)", fontsize=14)
plt.ylabel("Delivery Time (minutes)")
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()
